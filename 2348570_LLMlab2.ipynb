# %% [markdown]
# <a href="https://colab.research.google.com/github/victorjoseij/LLM/blob/main/2348570_LLMlab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Collecting langchain
#   Downloading langchain-0.2.8-py3-none-any.whl (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.6/987.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.19 (from langchain)
#   Downloading langchain_core-0.2.19-py3-none-any.whl (366 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.5/366.5 kB 10.4 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.86-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.19->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.19->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.19->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.8 langchain-core-0.2.19 langchain-text-splitters-0.2.2 langsmith-0.1.86 orjson-3.10.6
# Collecting langchain-groq
#   Downloading langchain_groq-0.1.6-py3-none-any.whl (14 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Downloading groq-0.9.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.2.19)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from groq<1,>=0.4.1->langchain-groq)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (0.1.86)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (8.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.0.7)
# Installing collected packages: h11, httpcore, httpx, groq, langchain-groq
# Successfully installed groq-0.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 langchain-groq-0.1.6

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is football')
# Out:
# 'A question that requires a nuanced answer!\n\nIn the United States, "football" typically refers to American football, a contact team sport played with an oval-shaped ball on a rectangular field with goalposts at each end. The objective is to score points by carrying or throwing the ball into the end zone of the opponent\'s field.\n\nIn the rest of the world, particularly in Europe, South America, Africa, and Asia, "football" usually refers to what Americans call "soccer." This version of the sport is played with a round ball on a larger field with goals at each end, and the objective is to score by kicking or heading the ball into the opponent\'s goal.\n\nHere\'s a brief overview of each:\n\n**American Football (US)**\n\n* Played with 11 players on each team\n* Game consists of four quarters, each lasting 15 minutes\n* Players can run with the ball (rush) or throw the ball to teammates (pass)\n* Points can be scored through touchdowns (6 points), field goals (3 points), and extra points (1 or 2 points)\n* Common positions include quarterback, running back, wide receiver, and defensive back\n\n**Association Football (Soccer)**\n\n* Played with 11 players on each team\n* Game consists of two 45-minute halves\n* Players primarily use their feet, legs, and heads to control and move the ball\n* Points can be scored through goals (1 point each)\n* Common positions include goalkeeper, defenders, midfielders, and forwards\n\nWhile both versions of football share some similarities, they have distinct rules, strategies, and cultures. The terminology used to describe the game can sometimes cause confusion, especially when discussing international matches or competitions.\n\nSo, which "football" do you have in mind?'

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
tell me about football
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# A great topic!
#
# Football, also known as American football, is a contact team sport played between two teams of 11 players each. The objective is to score points by carrying or throwing the ball into the end zone of the opponent's field.
#
# Here are some key aspects of football:
#
# **History**: Football originated in the United States in the mid-19th century, with the first intercollegiate game played in 1869 between Rutgers and Princeton universities.
#
# **Rules**: Each game is divided into four quarters, each lasting 15 minutes. The team with possession of the ball is called the offense, and they try to score by carrying or throwing the ball into the end zone. The team without the ball is called the defense, and they try to stop the offense from scoring by tackling them to the ground.
#
# **Scoring**: Points can be scored in several ways:
#
# * **Touchdown**: 6 points for carrying or throwing the ball into the end zone.
# * **Field Goal**: 3 points for kicking the ball through the opponent's goalposts.
# * **Safety**: 2 points for tackling an opponent in their own end zone or for a foul that results in a penalty.
#
# **Positions**: Each team has 11 players on the field, with different positions:
#
# * **Quarterback** (QB): The player who throws the ball and directs the offense.
# * **Running Back** (RB): The player who carries the ball and tries to gain yards.
# * **Wide Receiver** (WR): The player who catches passes from the quarterback.
# * **Linebacker** (LB): The player who defends against the run and pass.
# * **Defensive Back** (DB): The player who defends against passes.
#
# **Popular leagues**: The National Football League (NFL) is the most popular professional football league in the United States, followed by the College Football Playoff (CFP) and the National Collegiate Athletic Association (NCAA).
#
# **Super Bowl**: The championship game of the NFL, played between the winners of the American Football Conference (AFC) and National Football Conference (NFC) championships.
#
# **Fantasy Football**: A popular form of fantasy sports, where fans create virtual teams and compete against each other based on real-life football players' performances.
#
# **Impact**: Football is a massive industry, with millions of fans worldwide, and has inspired numerous movies, TV shows, and music.
#
# That's a brief overview of football! Do you have any specific questions or would you like to know more about a particular aspect of the sport?

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma-7b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is football')
# Out:
# "**Football** is a team sport in which two opposing teams compete to score points by carrying or passing the ball into their opponent's end zone.\n\n**Gameplay:**\n\n* The game is played on a rectangular field with a goal line at each end.\n* Each team has four downs to gain at least 10 yards to advance the ball down the field.\n* The offense (attack) attempts to score points by carrying or passing the ball into the end zone, while the defense (defense) tries to prevent the offense from scoring.\n* Points are scored by carrying or passing the ball into the end zone (6 points) or by kicking a field goal (3 points).\n\n**Basic Rules:**\n\n* The offense has four attempts (downs) to gain at least 10 yards to advance the ball.\n* If the offense fails to gain 10 yards in four downs, they turn the ball over to the defense.\n* The defense can score points by intercepting the ball, returning a fumble, or scoring a safety.\n* The team with the most points at the end of the game wins.\n\n**Positions:**\n\nFootball has various positions, including:\n\n* **Offense:** Quarterback, Running back, Wide receiver, Tight end, Center\n* **Defense:** Defensive tackle, Defensive end, Linebacker, Safety, Cornerback\n\n**Popularity:**\n\nFootball is one of the most popular sports in the world, with a passionate following in many countries. It is the most popular sport in the United States, where it is governed by the National Football League (NFL)."

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is football')
# Out:
# "Football, also known as soccer in some countries, is a team sport played with a ball between two teams of eleven players each. \n\nHere's a breakdown:\n\n**Objective:**\n\nThe objective of the game is to score by getting the ball into the opposing team's goal.\n\n**Gameplay:**\n\n* Players use their feet, head, and chest to control and pass the ball, but cannot use their hands or arms (except for the goalkeeper within their designated penalty area).\n* The team with the most goals at the end of the game wins.\n\n**Key Features:**\n\n* **Field:** Played on a rectangular field with a goal at each end.\n* **Players:** 11 players per team on the field at a time, including a goalkeeper.\n* **Duration:** Two 45-minute halves with a halftime break.\n* **Rules:** Governed by a set of rules established by the International Football Association Board (IFAB).\n\n**Popularity:**\n\nFootball is the most popular sport in the world, with billions of fans and players across every continent.\n\n**Variations:**\n\nThere are various forms of football, including:\n\n* **Association Football (Soccer):** The most common form, played internationally.\n* **American Football:** A different sport with its own set of rules and equipment.\n* **Rugby Football:** Involves carrying the ball and tackling.\n\n**Global Impact:**\n\nFootball has a significant cultural and economic impact, uniting people from different backgrounds and generating billions of dollars in revenue.\n\n\n\nLet me know if you have any other questions about football!\n"

# %% [markdown]
# From Gemini

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
